# %% [markdown]
# ![erd](images/ERD.png)

# %% [markdown]
# ## Instruction
#
# 1. ใช้ project myshop เดิมจากของ WEEK 4 มาทำต่อได้เลยครับ (ใครที่หา project ของ WEEK 4 ไม่เจอแล้ว ให้กลับไปทำตามขั้ยตอนใน week4_exercises.ipynb)
# 2. ใช้ database `shop` เดิมได้เลยเช่นกันครับ
#
# **หมายเหตุ: ถ้านักศึกษาใช้ database เดิมจาก WEEK4 ซึ่งนักศึกษาเคยเพิ่มหรือแก้ไขข้อมูลบางส่วนแล้ว ดังนั้น output อาจจะไม่ตรงกับในตัวอย่างทั้งหมดไม่ต้องตกใจนะครับ**

# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'myshop.settings')

import django
django.setup()

# import modules
from shop.models import *
from django.db.models import Count, Avg, Sum, F, Q

# %% [markdown]
# ### 1. annotate(), F()

# %% [markdown]
# 1.1 ให้นักศึกษาค้นหาข้อมูล `Payment` โดยให้เพิ่ม field ราคาที่ลบกับส่วนลดแล้ว โดยกำหนดให้ชื่อ field ว่า "after_discount_price" โดยใช้แสดงข้อมูล 10 ตัวแรกเรียงตาม "after_discount_price" จากมากไปน้อย (0.25 คะแนน)
#
# **หมายเหตุ: จะต้องใช้ annotate() นะครับ ให้เอา `Payment.price` - `Payment.discount`**
#
# ตัวอย่าง Output
#
# ```
# ID: 92, PRICE: 1200500.00, DISCOUNT 29433.25, AFTER_DISCOUNT 1171066.75
# ID: 82, PRICE: 1200280.00, DISCOUNT 46229.40, AFTER_DISCOUNT 1154050.60
# ID: 137, PRICE: 1200690.00, DISCOUNT 71407.25, AFTER_DISCOUNT 1129282.75
# ID: 105, PRICE: 1200390.00, DISCOUNT 105019.11, AFTER_DISCOUNT 1095370.89
# ID: 45, PRICE: 1218900.00, DISCOUNT 126859.95, AFTER_DISCOUNT 1092040.05
# ID: 7, PRICE: 1201200.00, DISCOUNT 113446.20, AFTER_DISCOUNT 1087753.80
# ID: 18, PRICE: 1202190.00, DISCOUNT 121922.64, AFTER_DISCOUNT 1080267.36
# ID: 77, PRICE: 379000.00, DISCOUNT 19397.00, AFTER_DISCOUNT 359603.00
# ID: 127, PRICE: 320450.00, DISCOUNT 14578.90, AFTER_DISCOUNT 305871.10
# ID: 125, PRICE: 320399.00, DISCOUNT 17939.55, AFTER_DISCOUNT 302459.45
# ```

# %%
# code here

payments = Payment.objects.all().annotate(after_discounted_price=F('price') - F('discount')).order_by('after_discounted_price')
for payment in payments:
    print(f'ID: {payment.id}, PRICE: {payment.price}, DISCOUNT {payment.discount}, AFTER_DISCOUNT {payment.after_discounted_price}')
# Out:
# ID: 49, PRICE: 290.00, DISCOUNT 16.66, AFTER_DISCOUNT 273.34
# ID: 78, PRICE: 400.00, DISCOUNT 37.10, AFTER_DISCOUNT 362.90
# ID: 56, PRICE: 439.00, DISCOUNT 19.26, AFTER_DISCOUNT 419.74
# ID: 13, PRICE: 470.00, DISCOUNT 21.46, AFTER_DISCOUNT 448.54
# ID: 40, PRICE: 540.00, DISCOUNT 46.94, AFTER_DISCOUNT 493.06
# ID: 58, PRICE: 539.00, DISCOUNT 32.09, AFTER_DISCOUNT 506.91
# ID: 54, PRICE: 540.00, DISCOUNT 17.33, AFTER_DISCOUNT 522.67
# ID: 184, PRICE: 550.00, DISCOUNT 25.90, AFTER_DISCOUNT 524.10
# ID: 62, PRICE: 600.00, DISCOUNT 56.70, AFTER_DISCOUNT 543.30
# ID: 22, PRICE: 590.00, DISCOUNT 30.94, AFTER_DISCOUNT 559.06
# ID: 9, PRICE: 599.00, DISCOUNT 23.09, AFTER_DISCOUNT 575.91
# ID: 5, PRICE: 590.00, DISCOUNT 10.29, AFTER_DISCOUNT 579.71
# ID: 166, PRICE: 640.00, DISCOUNT 50.86, AFTER_DISCOUNT 589.14
# ID: 3, PRICE: 700.00, DISCOUNT 46.55, AFTER_DISCOUNT 653.45
# ID: 31, PRICE: 700.00, DISCOUNT 44.10, AFTER_DISCOUNT 655.90
# ID: 177, PRICE: 690.00, DISCOUNT 24.89, AFTER_DISCOUNT 665.11
# ID: 181, PRICE: 700.00, DISCOUNT 33.25, AFTER_DISCOUNT 666.75
# ID: 17, PRICE: 699.00, DISCOUNT 24.82, AFTER_DISCOUNT 674.18
# ID: 128, PRICE: 730.00, DISCOUNT 45.61, AFTER_DISCOUNT 684.39
# ID: 144, PRICE: 730.00, DISCOUNT 25.97, AFTER_DISCOUNT 704.03
# ID: 57, PRICE: 780.00, DISCOUNT 61.43, AFTER_DISCOUNT 718.57
# ID: 90, PRICE: 789.00, DISCOUNT 43.91, AFTER_DISCOUNT 745.09
# ID: 67, PRICE: 780.00, DISCOUNT 34.37, AFTER_DISCOUNT 745.63
# ID: 69, PRICE: 800.00, DISCOUNT 50.75, AFTER_DISCOUNT 749.25
# ID: 84, PRICE: 800.00, DISCOUNT 49.70, AFTER_DISCOUNT 750.30
# ID: 55, PRICE: 849.00, DISCOUNT 67.28, AFTER_DISCOUNT 781.72
# ID: 120, PRICE: 890.00, DISCOUNT 90.34, AFTER_DISCOUNT 799.66
# ID: 98, PRICE: 899.00, DISCOUNT 76.90, AFTER_DISCOUNT 822.10
# ID: 115, PRICE: 890.00, DISCOUNT 55.65, AFTER_DISCOUNT 834.35
# ID: 119, PRICE: 890.00, DISCOUNT 14.04, AFTER_DISCOUNT 875.96
# ID: 95, PRICE: 990.00, DISCOUNT 58.70, AFTER_DISCOUNT 931.30
# ID: 89, PRICE: 1029.00, DISCOUNT 84.76, AFTER_DISCOUNT 944.24
# ID: 20, PRICE: 990.00, DISCOUNT 44.94, AFTER_DISCOUNT 945.06
# ID: 154, PRICE: 1000.00, DISCOUNT 45.50, AFTER_DISCOUNT 954.50
# ID: 171, PRICE: 990.00, DISCOUNT 32.34, AFTER_DISCOUNT 957.66
# ID: 48, PRICE: 1040.00, DISCOUNT 75.04, AFTER_DISCOUNT 964.96
# ID: 34, PRICE: 1140.00, DISCOUNT 99.79, AFTER_DISCOUNT 1040.21
# ID: 151, PRICE: 1140.00, DISCOUNT 47.36, AFTER_DISCOUNT 1092.64
# ID: 136, PRICE: 1140.00, DISCOUNT 42.32, AFTER_DISCOUNT 1097.68
# ID: 173, PRICE: 1200.00, DISCOUNT 96.25, AFTER_DISCOUNT 1103.75
# ID: 73, PRICE: 1229.00, DISCOUNT 119.73, AFTER_DISCOUNT 1109.27
# ID: 167, PRICE: 1150.00, DISCOUNT 16.63, AFTER_DISCOUNT 1133.37
# ID: 29, PRICE: 1190.00, DISCOUNT 44.45, AFTER_DISCOUNT 1145.55
# ID: 155, PRICE: 1290.00, DISCOUNT 110.67, AFTER_DISCOUNT 1179.33
# ID: 175, PRICE: 1290.00, DISCOUNT 107.31, AFTER_DISCOUNT 1182.69
# ID: 35, PRICE: 1299.00, DISCOUNT 81.85, AFTER_DISCOUNT 1217.15
# ID: 87, PRICE: 1290.00, DISCOUNT 67.83, AFTER_DISCOUNT 1222.17
# ID: 41, PRICE: 1400.00, DISCOUNT 97.30, AFTER_DISCOUNT 1302.70
# ID: 53, PRICE: 1400.00, DISCOUNT 93.10, AFTER_DISCOUNT 1306.90
# ID: 152, PRICE: 1380.00, DISCOUNT 50.72, AFTER_DISCOUNT 1329.28
# ID: 60, PRICE: 1490.00, DISCOUNT 112.04, AFTER_DISCOUNT 1377.96
# ID: 130, PRICE: 1480.00, DISCOUNT 93.24, AFTER_DISCOUNT 1386.76
# ID: 149, PRICE: 1490.00, DISCOUNT 94.36, AFTER_DISCOUNT 1395.64
# ID: 94, PRICE: 1550.00, DISCOUNT 126.18, AFTER_DISCOUNT 1423.82
# ID: 59, PRICE: 1499.00, DISCOUNT 68.18, AFTER_DISCOUNT 1430.82
# ID: 179, PRICE: 1580.00, DISCOUNT 73.36, AFTER_DISCOUNT 1506.64
# ID: 51, PRICE: 1649.00, DISCOUNT 89.74, AFTER_DISCOUNT 1559.26
# ID: 174, PRICE: 1700.00, DISCOUNT 130.73, AFTER_DISCOUNT 1569.27
# ID: 50, PRICE: 1699.00, DISCOUNT 112.27, AFTER_DISCOUNT 1586.73
# ID: 61, PRICE: 1740.00, DISCOUNT 140.81, AFTER_DISCOUNT 1599.19
# ID: 26, PRICE: 1720.00, DISCOUNT 116.41, AFTER_DISCOUNT 1603.59
# ID: 32, PRICE: 1690.00, DISCOUNT 85.61, AFTER_DISCOUNT 1604.39
# ID: 140, PRICE: 1890.00, DISCOUNT 79.28, AFTER_DISCOUNT 1810.72
# ID: 71, PRICE: 1980.00, DISCOUNT 158.77, AFTER_DISCOUNT 1821.23
# ID: 145, PRICE: 1920.00, DISCOUNT 33.60, AFTER_DISCOUNT 1886.40
# ID: 172, PRICE: 2080.00, DISCOUNT 163.39, AFTER_DISCOUNT 1916.61
# ID: 100, PRICE: 2190.00, DISCOUNT 137.24, AFTER_DISCOUNT 2052.76
# ID: 64, PRICE: 2199.00, DISCOUNT 81.12, AFTER_DISCOUNT 2117.88
# ID: 65, PRICE: 2480.00, DISCOUNT 181.38, AFTER_DISCOUNT 2298.62
# ID: 79, PRICE: 2399.00, DISCOUNT 80.81, AFTER_DISCOUNT 2318.19
# ID: 25, PRICE: 2540.00, DISCOUNT 208.15, AFTER_DISCOUNT 2331.85
# ID: 46, PRICE: 2700.00, DISCOUNT 275.10, AFTER_DISCOUNT 2424.90
# ID: 81, PRICE: 2580.00, DISCOUNT 93.03, AFTER_DISCOUNT 2486.97
# ID: 150, PRICE: 2699.00, DISCOUNT 143.10, AFTER_DISCOUNT 2555.90
# ID: 134, PRICE: 2850.00, DISCOUNT 171.15, AFTER_DISCOUNT 2678.85
# ID: 38, PRICE: 2890.00, DISCOUNT 70.18, AFTER_DISCOUNT 2819.82
# ID: 10, PRICE: 2890.00, DISCOUNT 67.73, AFTER_DISCOUNT 2822.27
# ID: 180, PRICE: 2898.00, DISCOUNT 69.61, AFTER_DISCOUNT 2828.39
# ID: 85, PRICE: 2900.00, DISCOUNT 22.40, AFTER_DISCOUNT 2877.60
# ID: 99, PRICE: 2949.00, DISCOUNT 60.02, AFTER_DISCOUNT 2888.98
# ID: 75, PRICE: 3189.00, DISCOUNT 263.64, AFTER_DISCOUNT 2925.36
# ID: 116, PRICE: 3090.00, DISCOUNT 122.64, AFTER_DISCOUNT 2967.36
# ID: 83, PRICE: 3100.00, DISCOUNT 115.85, AFTER_DISCOUNT 2984.15
# ID: 170, PRICE: 3200.00, DISCOUNT 211.40, AFTER_DISCOUNT 2988.60
# ID: 28, PRICE: 3399.00, DISCOUNT 203.65, AFTER_DISCOUNT 3195.35
# ID: 133, PRICE: 3500.00, DISCOUNT 291.55, AFTER_DISCOUNT 3208.45
# ID: 33, PRICE: 3280.00, DISCOUNT 30.84, AFTER_DISCOUNT 3249.16
# ID: 160, PRICE: 3650.00, DISCOUNT 282.80, AFTER_DISCOUNT 3367.20
# ID: 12, PRICE: 3499.00, DISCOUNT 127.70, AFTER_DISCOUNT 3371.30
# ID: 126, PRICE: 3700.00, DISCOUNT 257.25, AFTER_DISCOUNT 3442.75
# ID: 139, PRICE: 3700.00, DISCOUNT 226.45, AFTER_DISCOUNT 3473.55
# ID: 157, PRICE: 3789.00, DISCOUNT 180.30, AFTER_DISCOUNT 3608.70
# ID: 111, PRICE: 3990.00, DISCOUNT 268.59, AFTER_DISCOUNT 3721.41
# ID: 44, PRICE: 3990.00, DISCOUNT 210.11, AFTER_DISCOUNT 3779.89
# ID: 68, PRICE: 4139.00, DISCOUNT 342.09, AFTER_DISCOUNT 3796.91
# ID: 42, PRICE: 4390.00, DISCOUNT 373.21, AFTER_DISCOUNT 4016.79
# ID: 43, PRICE: 4190.00, DISCOUNT 165.31, AFTER_DISCOUNT 4024.69
# ID: 6, PRICE: 4300.00, DISCOUNT 195.65, AFTER_DISCOUNT 4104.35
# ID: 52, PRICE: 4200.00, DISCOUNT 86.10, AFTER_DISCOUNT 4113.90
# ID: 14, PRICE: 4480.00, DISCOUNT 333.31, AFTER_DISCOUNT 4146.69
# ID: 102, PRICE: 4500.00, DISCOUNT 320.25, AFTER_DISCOUNT 4179.75
# ID: 135, PRICE: 4350.00, DISCOUNT 142.80, AFTER_DISCOUNT 4207.20
# ID: 104, PRICE: 4490.00, DISCOUNT 94.64, AFTER_DISCOUNT 4395.36
# ID: 70, PRICE: 4899.00, DISCOUNT 180.23, AFTER_DISCOUNT 4718.77
# ID: 24, PRICE: 4890.00, DISCOUNT 164.96, AFTER_DISCOUNT 4725.04
# ID: 138, PRICE: 4800.00, DISCOUNT 48.30, AFTER_DISCOUNT 4751.70
# ID: 16, PRICE: 5390.00, DISCOUNT 483.67, AFTER_DISCOUNT 4906.33
# ID: 72, PRICE: 5190.00, DISCOUNT 265.23, AFTER_DISCOUNT 4924.77
# ID: 66, PRICE: 5590.00, DISCOUNT 346.54, AFTER_DISCOUNT 5243.46
# ID: 23, PRICE: 5689.00, DISCOUNT 360.83, AFTER_DISCOUNT 5328.17
# ID: 158, PRICE: 6139.00, DISCOUNT 442.85, AFTER_DISCOUNT 5696.15
# ID: 15, PRICE: 6290.00, DISCOUNT 288.93, AFTER_DISCOUNT 6001.07
# ID: 148, PRICE: 6590.00, DISCOUNT 562.14, AFTER_DISCOUNT 6027.86
# ID: 11, PRICE: 6499.00, DISCOUNT 468.96, AFTER_DISCOUNT 6030.04
# ID: 162, PRICE: 6400.00, DISCOUNT 369.60, AFTER_DISCOUNT 6030.40
# ID: 182, PRICE: 6499.00, DISCOUNT 351.73, AFTER_DISCOUNT 6147.27
# ID: 161, PRICE: 6350.00, DISCOUNT 31.68, AFTER_DISCOUNT 6318.32
# ID: 168, PRICE: 7990.00, DISCOUNT 665.81, AFTER_DISCOUNT 7324.19
# ID: 113, PRICE: 8190.00, DISCOUNT 316.33, AFTER_DISCOUNT 7873.67
# ID: 121, PRICE: 7990.00, DISCOUNT 113.44, AFTER_DISCOUNT 7876.56
# ID: 37, PRICE: 8200.00, DISCOUNT 277.55, AFTER_DISCOUNT 7922.45
# ID: 122, PRICE: 8139.00, DISCOUNT 199.41, AFTER_DISCOUNT 7939.59
# ID: 110, PRICE: 8399.00, DISCOUNT 428.32, AFTER_DISCOUNT 7970.68
# ID: 88, PRICE: 9320.00, DISCOUNT 978.60, AFTER_DISCOUNT 8341.40
# ID: 30, PRICE: 9499.00, DISCOUNT 883.75, AFTER_DISCOUNT 8615.25
# ID: 117, PRICE: 9290.00, DISCOUNT 566.16, AFTER_DISCOUNT 8723.84
# ID: 36, PRICE: 9390.00, DISCOUNT 612.15, AFTER_DISCOUNT 8777.85
# ID: 39, PRICE: 9500.00, DISCOUNT 712.25, AFTER_DISCOUNT 8787.75
# ID: 4, PRICE: 9350.00, DISCOUNT 481.78, AFTER_DISCOUNT 8868.22
# ID: 118, PRICE: 9690.00, DISCOUNT 809.13, AFTER_DISCOUNT 8880.87
# ID: 47, PRICE: 9690.00, DISCOUNT 656.46, AFTER_DISCOUNT 9033.54
# ID: 169, PRICE: 9700.00, DISCOUNT 458.50, AFTER_DISCOUNT 9241.50
# ID: 142, PRICE: 9990.00, DISCOUNT 745.29, AFTER_DISCOUNT 9244.71
# ID: 159, PRICE: 9400.00, DISCOUNT 115.50, AFTER_DISCOUNT 9284.50
# ID: 101, PRICE: 9700.00, DISCOUNT 231.00, AFTER_DISCOUNT 9469.00
# ID: 108, PRICE: 9990.00, DISCOUNT 429.98, AFTER_DISCOUNT 9560.02
# ID: 153, PRICE: 11090.00, DISCOUNT 1071.49, AFTER_DISCOUNT 10018.51
# ID: 146, PRICE: 10900.00, DISCOUNT 199.15, AFTER_DISCOUNT 10700.85
# ID: 106, PRICE: 11400.00, DISCOUNT 348.60, AFTER_DISCOUNT 11051.40
# ID: 107, PRICE: 19100.00, DISCOUNT 1665.65, AFTER_DISCOUNT 17434.35
# ID: 129, PRICE: 18800.00, DISCOUNT 836.15, AFTER_DISCOUNT 17963.85
# ID: 80, PRICE: 19250.00, DISCOUNT 662.73, AFTER_DISCOUNT 18587.27
# ID: 8, PRICE: 21900.00, DISCOUNT 2002.35, AFTER_DISCOUNT 19897.65
# ID: 112, PRICE: 22900.00, DISCOUNT 2306.50, AFTER_DISCOUNT 20593.50
# ID: 164, PRICE: 22900.00, DISCOUNT 136.15, AFTER_DISCOUNT 22763.85
# ID: 114, PRICE: 26299.00, DISCOUNT 2645.20, AFTER_DISCOUNT 23653.80
# ID: 109, PRICE: 26499.00, DISCOUNT 1279.20, AFTER_DISCOUNT 25219.80
# ID: 97, PRICE: 26800.00, DISCOUNT 805.70, AFTER_DISCOUNT 25994.30
# ID: 123, PRICE: 28999.00, DISCOUNT 2785.90, AFTER_DISCOUNT 26213.10
# ID: 163, PRICE: 27199.00, DISCOUNT 837.17, AFTER_DISCOUNT 26361.83
# ID: 91, PRICE: 32390.00, DISCOUNT 2933.84, AFTER_DISCOUNT 29456.16
# ID: 86, PRICE: 32800.00, DISCOUNT 1705.20, AFTER_DISCOUNT 31094.80
# ID: 74, PRICE: 32700.00, DISCOUNT 1183.70, AFTER_DISCOUNT 31516.30
# ID: 143, PRICE: 32999.00, DISCOUNT 1340.47, AFTER_DISCOUNT 31658.53
# ID: 124, PRICE: 32300.00, DISCOUNT 459.55, AFTER_DISCOUNT 31840.45
# ID: 131, PRICE: 36000.00, DISCOUNT 2912.00, AFTER_DISCOUNT 33088.00
# ID: 141, PRICE: 37900.00, DISCOUNT 1176.35, AFTER_DISCOUNT 36723.65
# ID: 147, PRICE: 59300.00, DISCOUNT 4978.05, AFTER_DISCOUNT 54321.95
# ID: 63, PRICE: 59690.00, DISCOUNT 4190.38, AFTER_DISCOUNT 55499.62
# ID: 93, PRICE: 59300.00, DISCOUNT 3742.20, AFTER_DISCOUNT 55557.80
# ID: 19, PRICE: 59690.00, DISCOUNT 3107.16, AFTER_DISCOUNT 56582.84
# ID: 96, PRICE: 59500.00, DISCOUNT 2730.00, AFTER_DISCOUNT 56770.00
# ID: 165, PRICE: 63000.00, DISCOUNT 4903.50, AFTER_DISCOUNT 58096.50
# ID: 185, PRICE: 59450.00, DISCOUNT 840.18, AFTER_DISCOUNT 58609.82
# ID: 132, PRICE: 66900.00, DISCOUNT 6375.60, AFTER_DISCOUNT 60524.40
# ID: 176, PRICE: 75000.00, DISCOUNT 7192.50, AFTER_DISCOUNT 67807.50
# ID: 76, PRICE: 70700.00, DISCOUNT 1029.00, AFTER_DISCOUNT 69671.00
# ID: 156, PRICE: 70300.00, DISCOUNT 501.55, AFTER_DISCOUNT 69798.45
# ID: 21, PRICE: 84999.00, DISCOUNT 2936.40, AFTER_DISCOUNT 82062.60
# ID: 183, PRICE: 102000.00, DISCOUNT 2408.00, AFTER_DISCOUNT 99592.00
# ID: 103, PRICE: 129000.00, DISCOUNT 3535.00, AFTER_DISCOUNT 125465.00
# ID: 27, PRICE: 322499.00, DISCOUNT 33827.41, AFTER_DISCOUNT 288671.59
# ID: 178, PRICE: 324000.00, DISCOUNT 28042.00, AFTER_DISCOUNT 295958.00
# ID: 125, PRICE: 320399.00, DISCOUNT 17939.55, AFTER_DISCOUNT 302459.45
# ID: 127, PRICE: 320450.00, DISCOUNT 14578.90, AFTER_DISCOUNT 305871.10
# ID: 77, PRICE: 379000.00, DISCOUNT 19397.00, AFTER_DISCOUNT 359603.00
# ID: 18, PRICE: 1202190.00, DISCOUNT 121922.64, AFTER_DISCOUNT 1080267.36
# ID: 7, PRICE: 1201200.00, DISCOUNT 113446.20, AFTER_DISCOUNT 1087753.80
# ID: 45, PRICE: 1218900.00, DISCOUNT 126859.95, AFTER_DISCOUNT 1092040.05
# ID: 105, PRICE: 1200390.00, DISCOUNT 105019.11, AFTER_DISCOUNT 1095370.89
# ID: 137, PRICE: 1200690.00, DISCOUNT 71407.25, AFTER_DISCOUNT 1129282.75
# ID: 82, PRICE: 1200280.00, DISCOUNT 46229.40, AFTER_DISCOUNT 1154050.60
# ID: 92, PRICE: 1200500.00, DISCOUNT 29433.25, AFTER_DISCOUNT 1171066.75

# %% [markdown]
# 1.2 ต่อเนื่องจากข้อ 1.1 ให้ filter เฉพาะข้อมูล `Payment` ที่มี "after_discount_price" มากกว่า 500,000 (0.25 คะแนน)
#
# ตัวอย่าง Output
#
# ```
# ID: 92, PRICE: 1200500.00, DISCOUNT 29433.25, AFTER_DISCOUNT 1171066.75
# ID: 82, PRICE: 1200280.00, DISCOUNT 46229.40, AFTER_DISCOUNT 1154050.60
# ID: 137, PRICE: 1200690.00, DISCOUNT 71407.25, AFTER_DISCOUNT 1129282.75
# ID: 105, PRICE: 1200390.00, DISCOUNT 105019.11, AFTER_DISCOUNT 1095370.89
# ID: 45, PRICE: 1218900.00, DISCOUNT 126859.95, AFTER_DISCOUNT 1092040.05
# ID: 7, PRICE: 1201200.00, DISCOUNT 113446.20, AFTER_DISCOUNT 1087753.80
# ID: 18, PRICE: 1202190.00, DISCOUNT 121922.64, AFTER_DISCOUNT 1080267.36
# ```

# %%
# code here

payments = Payment.objects.annotate(after_discount_price=F('price') - F('discount')).filter(after_discount_price__gt=500000).order_by('after_discount_price')
for payment in payments:
    print(f'{payment.id} {payment.price} {payment.discount} {payment.after_discount_price}')
# Out:
# 18 1202190.00 121922.64 1080267.36
# 7 1201200.00 113446.20 1087753.80
# 45 1218900.00 126859.95 1092040.05
# 105 1200390.00 105019.11 1095370.89
# 137 1200690.00 71407.25 1129282.75
# 82 1200280.00 46229.40 1154050.60
# 92 1200500.00 29433.25 1171066.75

# %% [markdown]
# 1.3 ให้นักศึกษาเรียงลำดับข้อมูลลูกค้า (`Customer`) โดยเรียงลำดับตามลำดับตัวอักษร `น้อยไปมาก` จากชื่อเต็มของลูกค้า (`full_name`) โดยแสดง 5 คนแรก (0.5 คะแนน)
#
# **Hint:** Field `full_name` นั้นจะต้องถูก annotate ขึ้นมาโดยการนำ `first_name` มาต่อกับ `last_name` โดยใช้ `Concat(*expressions, **extra)`
#
# **Hint:** แปลง object เป็น dict ใช้ `values()` [doc](https://docs.djangoproject.com/en/5.0/ref/models/querysets/#values)
#
# ```python
# >>> Blog.objects.filter(name__startswith="Beatles").values()
# <QuerySet [{'id': 1, 'name': 'Beatles Blog', 'tagline': 'All the latest Beatles news.'}]>
# ```
#
# **Hint:** อยาก print dictionary สวยๆ ใช้ `json.dumps`
#
# ```python
# print(json.dumps(dictionary, indent=4, sort_keys=False))
# ```
#
# [doc](https://docs.djangoproject.com/en/5.0/ref/models/database-functions/#concat)
#
# ตัวอย่าง Output
#
# ```python
# {
#     "id": 17,
#     "email": "anantaya.deena@gmail.com",
#     "address": {
#         "district": "Yan Nawa",
#         "location": "60 Thanon Chan Road",
#         "province": "Bangkok",
#         "postal_code": 10120
#     },
#     "full_name": "Anantaya Tontong"
# }
# {
#     "id": 25,
#     "email": "bancha.zeyou@gmail.com",
#     "address": {
#         "district": "Watthana",
#         "location": "6 Thong Lo Road",
#         "province": "Bangkok",
#         "postal_code": 10110
#     },
#     "full_name": "Bancha Kittisompong"
# }
# {
#     "id": 19,
#     "email": "chayapol.231@gmail.com",
#     "address": {
#         "district": "Hang Chat",
#         "location": "160 Lampang Road",
#         "province": "Lampang",
#         "postal_code": 52190
#     },
#     "full_name": "Chayapol Komprach"
# }
# {
#     "id": 4,
#     "email": "dejwit.tt@gmail.com",
#     "address": {
#         "district": "Chiang Khan",
#         "location": "150 Loei Road",
#         "province": "Loei",
#         "postal_code": 42110
#     },
#     "full_name": "Dejwit Tangjareonsakul"
# }
# {
#     "id": 11,
#     "email": "jack.maa@gmail.com",
#     "address": {
#         "district": "Bang Khen",
#         "location": "88 Phahonyothin Road",
#         "province": "Bangkok",
#         "postal_code": 10220
#     },
#     "full_name": "Jack Maa"
# }
#
# ```

# %% [markdown]
# # code here

# %% [markdown]
# ### 3. aggregation - count(), sum(), AVG()

# %% [markdown]
# 3.1 ให้นักศึกษาหาค่าเฉลี่ยของราคาสินค้า (`Product.price`) ที่มีจำนวนคงเหลือ (`Product.remaining_amount`) มากกว่า 0 (0.25 คะแนน)
#
# ``` PYTHON
# {'avg': Decimal('29308.000000000000')}
# ```

# %%
# code here
from django.db.models.functions import Concat
from django.db.models import Count, Avg, Sum, F, Q, Value
import json as json

customers = list(Customer.objects.annotate(full_name=Concat('first_name', Value(" "), "last_name")).values())
jsondumped = json.dumps(customers, indent=4)
print(jsondumped)
# Out:
# [
#     {
#         "id": 1,
#         "first_name": "Panita",
#         "last_name": "Hongsakulpan",
#         "email": "panita.hong@gmail.com",
#         "address": {
#             "district": "Khlong Toei",
#             "location": "87/2 Sukhumvit Road",
#             "province": "Bangkok",
#             "postal_code": 10110
#         },
#         "full_name": "Panita Hongsakulpan"
#     },
#     {
#         "id": 2,
#         "first_name": "Pakin",
#         "last_name": "Janpen",
#         "email": "pakin.jan@gmail.com",
#         "address": {
#             "district": "Chatuchak",
#             "location": "110 Vibhavadi Rangsit Road",
#             "province": "Bangkok",
#             "postal_code": 10900
#         },
#         "full_name": "Pakin Janpen"
#     },
#     {
#         "id": 3,
#         "first_name": "Jenjira",
#         "last_name": "Sukanansarn",
#         "email": "jenjira.su@gmail.com",
#         "address": {
#             "district": "Muang",
#             "location": "22 Moo 4, Chiangmai-Hod Road",
#             "province": "Chiang Mai",
#             "postal_code": 50000
#         },
#         "full_name": "Jenjira Sukanansarn"
#     },
#     {
#         "id": 4,
#         "first_name": "Dejwit",
#         "last_name": "Tangjareonsakul",
#         "email": "dejwit.tt@gmail.com",
#         "address": {
#             "district": "Chiang Khan",
#             "location": "150 Loei Road",
#             "province": "Loei",
#             "postal_code": 42110
#         },
#         "full_name": "Dejwit Tangjareonsakul"
#     },
#     {
#         "id": 5,
#         "first_name": "Pong",
#         "last_name": "Sawadiwong",
#         "email": "pong.23@gmail.com",
#         "address": {
#             "district": "Pa Sang",
#             "location": "37 Lamphun Road",
#             "province": "Lamphun",
#             "postal_code": 51120
#         },
#         "full_name": "Pong Sawadiwong"
#     },
#     {
#         "id": 6,
#         "first_name": "Thitirat",
#         "last_name": "Sukkesorn",
#         "email": "thiti.za@gmail.com",
#         "address": {
#             "district": "Prakhon Chai",
#             "location": "101 Buriram Road",
#             "province": "Buriram",
#             "postal_code": 31140
#         },
#         "full_name": "Thitirat Sukkesorn"
#     },
#     {
#         "id": 7,
#         "first_name": "Porntipa",
#         "last_name": "Pasakul",
#         "email": "prontipa.za@gmail.com",
#         "address": {
#             "district": "Bang Rak",
#             "location": "22 Silom Road",
#             "province": "Bangkok",
#             "postal_code": 10500
#         },
#         "full_name": "Porntipa Pasakul"
#     },
#     {
#         "id": 8,
#         "first_name": "Warit",
#         "last_name": "Pititat",
#         "email": "warit.za@gmail.com",
#         "address": {
#             "district": "Bang Rak",
#             "location": "29/1 Silom Road",
#             "province": "Bangkok",
#             "postal_code": 10500
#         },
#         "full_name": "Warit Pititat"
#     },
#     {
#         "id": 9,
#         "first_name": "Sira",
#         "last_name": "Pititat",
#         "email": "sira.za@gmail.com",
#         "address": {
#             "district": "Bang Rak",
#             "location": "29/1 Silom Road",
#             "province": "Bangkok",
#             "postal_code": 10500
#         },
#         "full_name": "Sira Pititat"
#     },
#     {
#         "id": 10,
#         "first_name": "Wanaporn",
#         "last_name": "Klabpetch",
#         "email": "wanaporn.over@gmail.com",
#         "address": {
#             "district": "Huai Khwang",
#             "location": "99 Rama IX Road",
#             "province": "Bangkok",
#             "postal_code": 10310
#         },
#         "full_name": "Wanaporn Klabpetch"
#     },
#     {
#         "id": 11,
#         "first_name": "Jack",
#         "last_name": "Maa",
#         "email": "jack.maa@gmail.com",
#         "address": {
#             "district": "Bang Khen",
#             "location": "88 Phahonyothin Road",
#             "province": "Bangkok",
#             "postal_code": 10220
#         },
#         "full_name": "Jack Maa"
#     },
#     {
#         "id": 12,
#         "first_name": "Jakkapob",
#         "last_name": "Sopapak",
#         "email": "jakkapob@gmail.com",
#         "address": {
#             "district": "Lat Phrao",
#             "location": "44/1 Lat Phrao Road",
#             "province": "Bangkok",
#             "postal_code": 10230
#         },
#         "full_name": "Jakkapob Sopapak"
#     },
#     {
#         "id": 13,
#         "first_name": "Kittitorn",
#         "last_name": "Wilairat",
#         "email": "kittitorn@gmail.com",
#         "address": {
#             "district": "Lat Phrao",
#             "location": "8 Lat Phrao Road",
#             "province": "Bangkok",
#             "postal_code": 10230
#         },
#         "full_name": "Kittitorn Wilairat"
#     },
#     {
#         "id": 14,
#         "first_name": "Yanisa",
#         "last_name": "Nantapak",
#         "email": "yanisa.ok@gmail.com",
#         "address": {
#             "district": "Bang Kapi",
#             "location": "66 Ramkhamhaeng Road",
#             "province": "Bangkok",
#             "postal_code": 10240
#         },
#         "full_name": "Yanisa Nantapak"
#     },
#     {
#         "id": 15,
#         "first_name": "stave",
#         "last_name": "klolas",
#         "email": "mr.stave@gmail.com",
#         "address": {
#             "district": "Bang Kapi",
#             "location": "23 Ramkhamhaeng Road",
#             "province": "Bangkok",
#             "postal_code": 10240
#         },
#         "full_name": "stave klolas"
#     },
#     {
#         "id": 16,
#         "first_name": "Peeraya",
#         "last_name": "Wichienchan",
#         "email": "peeraya.nock@gmail.com",
#         "address": {
#             "district": "Lak Si",
#             "location": "55 Vibhavadi Rangsit Road",
#             "province": "Bangkok",
#             "postal_code": 10210
#         },
#         "full_name": "Peeraya Wichienchan"
#     },
#     {
#         "id": 17,
#         "first_name": "Anantaya",
#         "last_name": "Tontong",
#         "email": "anantaya.deena@gmail.com",
#         "address": {
#             "district": "Yan Nawa",
#             "location": "60 Thanon Chan Road",
#             "province": "Bangkok",
#             "postal_code": 10120
#         },
#         "full_name": "Anantaya Tontong"
#     },
#     {
#         "id": 18,
#         "first_name": "Sek",
#         "last_name": "Loso",
#         "email": "seke.loso@gmail.com",
#         "address": {
#             "district": "Yan Nawa",
#             "location": "1 Thanon Chan Road",
#             "province": "Bangkok",
#             "postal_code": 10120
#         },
#         "full_name": "Sek Loso"
#     },
#     {
#         "id": 19,
#         "first_name": "Chayapol",
#         "last_name": "Komprach",
#         "email": "chayapol.231@gmail.com",
#         "address": {
#             "district": "Hang Chat",
#             "location": "160 Lampang Road",
#             "province": "Lampang",
#             "postal_code": 52190
#         },
#         "full_name": "Chayapol Komprach"
#     },
#     {
#         "id": 20,
#         "first_name": "Kerikwan",
#         "last_name": "Laopong",
#         "email": "kerikwan.laop@gmail.com",
#         "address": {
#             "district": "Pa Sang",
#             "location": "37 Lamphun Road",
#             "province": "Lamphun",
#             "postal_code": 51120
#         },
#         "full_name": "Kerikwan Laopong"
#     },
#     {
#         "id": 21,
#         "first_name": "Phuwadech",
#         "last_name": "Siriwanich",
#         "email": "phuwadech.01@gmail.com",
#         "address": {
#             "district": "Thung Song",
#             "location": "89 Nakhon Si Thammarat Road",
#             "province": "Nakhon Si Thammarat",
#             "postal_code": 80110
#         },
#         "full_name": "Phuwadech Siriwanich"
#     },
#     {
#         "id": 22,
#         "first_name": "Manit",
#         "last_name": "Senapan",
#         "email": "phuwadech.01@gmail.com",
#         "address": {
#             "district": "Lang Suan",
#             "location": "101 Chumphon Road",
#             "province": "Chumphon",
#             "postal_code": 86110
#         },
#         "full_name": "Manit Senapan"
#     },
#     {
#         "id": 23,
#         "first_name": "Yanisa",
#         "last_name": "Thongchaiyapoom",
#         "email": "yanisa.game888@gmail.com",
#         "address": {
#             "district": "Paknampho",
#             "location": "200 Nakhon Sawan Road",
#             "province": "Nakhon Sawan",
#             "postal_code": 60000
#         },
#         "full_name": "Yanisa Thongchaiyapoom"
#     },
#     {
#         "id": 24,
#         "first_name": "Rachanon",
#         "last_name": "Hongpatra",
#         "email": "rachanon.321@gmail.com",
#         "address": {
#             "district": "Pathum Wan",
#             "location": "75/2 Wireless Road",
#             "province": "Bangkok",
#             "postal_code": 10330
#         },
#         "full_name": "Rachanon Hongpatra"
#     },
#     {
#         "id": 25,
#         "first_name": "Bancha",
#         "last_name": "Kittisompong",
#         "email": "bancha.zeyou@gmail.com",
#         "address": {
#             "district": "Watthana",
#             "location": "6 Thong Lo Road",
#             "province": "Bangkok",
#             "postal_code": 10110
#         },
#         "full_name": "Bancha Kittisompong"
#     },
#     {
#         "id": 26,
#         "first_name": "Pattanapoom",
#         "last_name": "Srisawangjan",
#         "email": "pattanapoom.zabbc@gmail.com",
#         "address": {
#             "district": "Mueang",
#             "location": "123 Chaiyaphum Road",
#             "province": "Chaiyaphum",
#             "postal_code": 36000
#         },
#         "full_name": "Pattanapoom Srisawangjan"
#     },
#     {
#         "id": 27,
#         "first_name": "Techathorn",
#         "last_name": "Sriwanwilai",
#         "email": "sriwanwilai.1@gmail.com",
#         "address": {
#             "district": "Hat Yai",
#             "location": "56 Kanchanavanich Road",
#             "province": "Songkhla",
#             "postal_code": 90110
#         },
#         "full_name": "Techathorn Sriwanwilai"
#     },
#     {
#         "id": 28,
#         "first_name": "Kwantip",
#         "last_name": "Aekopas",
#         "email": "aekopas.za@gmail.com",
#         "address": {
#             "district": "Mueang",
#             "location": "78 Mittraphap Road",
#             "province": "Nakhon Ratchasima",
#             "postal_code": 30000
#         },
#         "full_name": "Kwantip Aekopas"
#     },
#     {
#         "id": 29,
#         "first_name": "Suwichada",
#         "last_name": "Jarastham",
#         "email": "suwichada.za@gmail.com",
#         "address": {
#             "district": "Mueang",
#             "location": "22 Krabi Road",
#             "province": "Krabi",
#             "postal_code": 81000
#         },
#         "full_name": "Suwichada Jarastham"
#     },
#     {
#         "id": 30,
#         "first_name": "Trinnapon",
#         "last_name": "Yinggnam",
#         "email": "trinnapon.091@gmail.com",
#         "address": {
#             "district": "Watthana",
#             "location": "50 Sukhumvit Soi 11",
#             "province": "Bangkok",
#             "postal_code": 10110
#         },
#         "full_name": "Trinnapon Yinggnam"
#     }
# ]

# %% [markdown]
# 3.2 จงหาผลรวมราคา (`CartItem.product.price`) ที่อยู่ในตระกร้าสินค้าของเดือน `พฤษภาคม` (ดูจาก `Cart.create_date`) (0.5 คะแนน)
#
# ```PYTHON
# {'sum': Decimal('9912555.00')}
#
# ```

# %%
# code here
sum_price = CartItem.objects.annotate(sum_price=F('amount') * F('product__price')).filter(cart__create_date__month=5).aggregate(Sum('sum_price'))
data = list(sum_price.values())
print(data)
# Out:
# [Decimal('21163645.00')]

# %% [markdown]
# 3.3 ให้นักศึกษานับจำนวนสินค้าที่อยู่ประเภท `Electronics`,  `Jewelry` และ ราคาของสินค้าอยู่ในช่วง 8,000.00 - 50,000.00 (0.25 คะแนน)
#
# ```
# PRODUCT CATEGORY NAME: Electronics, PRODUCT COUNT: 6
# PRODUCT CATEGORY NAME: Jewelry, PRODUCT COUNT: 1
# ```

# %%
# code here

# products = Product.objects.filter(Q(categories__name = 'Electronics') | Q(categories__name = 'Jewelry')).filter(Q(price__gte=8000) | Q(price__lte=50000)).annotate(Count('categories'))
electronics = Product.objects.filter(categories__name="Electronics").filter(price__gt=8000, price__lt=50000).aggregate(Count('categories'))

jewelrry = Product.objects.filter(categories__name="Jewelry").filter(price__gt=8000, price__lt=50000).aggregate(Count('categories'))

print(f'PRODUCT CATEGORY NAME: Electronics, PRODUCT COUNT: {electronics["categories__count"]}')
print(f'PRODUCT CATEGORY NAME: Jewelry, PRODUCT COUNT: {jewelrry["categories__count"]}')
# Out:
# {'categories__count': 7}
# {'categories__count': 1}
# PRODUCT CATEGORY NAME: Electronics, PRODUCT COUNT: 7
# PRODUCT CATEGORY NAME: Jewelry, PRODUCT COUNT: 1

# %% [markdown]
# ### 4. one-to-one & one-to-many

# %% [markdown]
# 4.1 ให้นักศึกษาทำการ INSERT ข้อมูลใบสั่งซื้อ (`Order`) และการชำระเงิน (`Payment`) ของลูกค้าชื่อ `Manit Senapan` ตามรายการดังนี้ให้สมบูรณ์ (0.5 คะแนน)
#
# **Hint:** ใน model `Payment` เรามีการเก็บค่า `price` เป็น Decimal ทำให้ค่าของราคาเป็น Decimal เช่นกัน)
# [Decimal](https://docs.python.org/3/library/decimal.html)
#
# - ออกใบสั่งซื้อวันที่ 5 สิงหาคม 2024
# - ชำระเงินวันที่ 6 สิงหาคม 2024
# - หมายเหตุ: `ฉันรวย อยากใช้เงินเยอะๆ`
#
#     โดย Manit สั่งสิ้นค้าดั่งนี้
#
#         - Diamond Stud Earrings จำนวน 1 ชิ้น
#
#         - Sofa จำนวน 2 ชิ้น
#
#         - Rose Gold Hoop Earrings จำนวน 1 ชิ้น
#
# - โดยที่ Manit ได้รับส่วนลดชิ้นละ 10 % ของสินค้า และมีการระบุหมายเหตุตอนชำระเงินว่า `ลูกค้า VIP ของเรา`
#
# - พร้อมชำระเงินโดยให้ 50 % ของราคาทั้งหมดชำระด้วยการแสกน QR code และที่เหลือชำระผ่านบัตรเคดิต
#
# - จากนั้นให้ระบบแสดงผลการสร้างใบสั่งซื้อ และการชำระเงินของ Manit ให้ถูกต้อง
#
#
# ตัวอย่าง output ที่ต้องการ
# ```PYTHON
# {
#     'order_id': 186,
#     'order_date': '2024-08-05',
#     'order_remark': 'ฉันรวย อยากใช้เงินเยอะๆ',
#     'products': [
#         {
#             'product': 'Diamond Stud Earrings',
#             'amount': 1,
#             'price': 320000.0,
#             'discount': 32000.0
#         },
#         {
#             'product': 'Sofa',
#             'amount': 2,
#             'price': 14000.0,
#             'discount': 1400.0
#         },
#         {
#             'product': 'Rose Gold Hoop Earrings',
#             'amount': 1,
#             'price': 1200000.0,
#             'discount': 120000.0
#         }
#     ],
#     'payment_date': '2024-08-06',
#     'payment_remark': 'ลูกค้า VIP ของเรา',
#     'payment_method': [
#         {
#             'method': 'QR',
#             'price': 767000.0
#         },
#         {
#             'method': 'CREDIT',
#             'price': 767000.0
#         }
#     ]
# }
#
# ```

# %%
# code here - INSERT

customer = Customer.objects.get(first_name='Manit', last_name='Senapan')

new_order = Order(
    customer=customer,
    remark='ฉันรวย อยากใช้เงินเยอะๆ',
    order_date='2024-08-05'
)

new_order.save()

earring = Product.objects.get(name='Diamond Stud Earrings')
sofa = Product.objects.get(name='Sofa')
earring2 = Product.objects.get(name='Rose Gold Hoop Earrings')

order_item_1 = OrderItem(
    order=new_order,
    product=earring,
    amount=1
)

order_item_1.save()

order_item_2 = OrderItem(
    order=new_order,
    product=sofa,
    amount=2
)

order_item_2.save()

order_item_3 = OrderItem(
    order=new_order,
    product=earring2,
    amount=1
)

order_item_3.save()

# %%
# payment

# %%
# code here - แสดงผล

# %% [markdown]
# ### 5. many-to-many

# %% [markdown]
# 5.1 ให้นักศึกษาค้นหาข้อมูลสินค้า (`Product`) ที่อยู่ในประเภทสินค้า "Information Technology" 10 รายการแรก (เรียงลำดับด้วย `Product.id`) และแสดงชื่อประเภทสินค้า (`ProductCategory`) (0.25 คะแนน)
#
# ตัวอย่าง Output บางส่วน
#
# ```
# PRODUCT ID: 1, PRODUCT NAME: Smartphone, PRODUCT CATEGORY: Information technology, Electronics
# PRODUCT ID: 2, PRODUCT NAME: Laptop, PRODUCT CATEGORY: Information technology, Electronics
# PRODUCT ID: 3, PRODUCT NAME: Smart TV, PRODUCT CATEGORY: Information technology, Electronics
# ```

# %%
# code here

products = Product.objects.filter(
    categories__name="Information Technology"
).order_by("id")[:10]

for product in products:
    print(f'{product.id} {product.name} {product.price}')
# Out:
# 1 Smartphone 5900.00
# 2 Laptop 25999.00
# 3 Smart TV 8900.00
# 4 Bluetooth Earphones 350.00
# 5 Tablet 12900.00
# 6 Gaming Console 5000.00
# 7 Digital Camera 32000.00
# 8 Wireless Router 990.00
# 9 Portable Power Bank 390.00
# 10 Smartwatch 4500.00

# %% [markdown]
# 5.2 ให้นักศึกษาทำตามขั้นตอนดังนี้ (0.25 คะแนน)
#
# **หมายเหตุ: ถ้าใช้ DB จาก WEEK4 `Books and Media` อาจจะถูกเปลี่ยนเป็น `Books` แล้ว**
#
#     1. เปลี่ยนชื่อประเภทสินค้า `Books and Media` เป็น `Books and Toys`
#     2. ลบประเภท `Toys and Games` ออกโดยให้ใช้เป็น `Books and Toys` แทน
#     3. ค้นหาว่าสินค้าที่มีประเภทสินค้าเป็น `Books and Toys` ทั้งหมดมีจำนวนเท่าไหร่

# %%
# code here

book_cateogory = ProductCategory.objects.get(name='Books and Toys')
# book_cateogory.name = 'Books and Toys'
# book_cateogory.save()

# toy_and_game = ProductCategory.objects.get(name='Toys and Games')
# toy_and_game.delete()

furnitures = ProductCategory.objects.filter(name='Furniture')
products = Product.objects.filter(categories__name='Furiniture')
for product in products:
    product.categories.add(book_cateogory)
    product.categories.remove(furnitures)
furnitures.delete()

product = Product.objects.filter(categories__name='Books and Toys').count()
print(f'PRODUCT COUNT: {product}')
# Out:
# PRODUCT COUNT: 0
